# %%
from scipy.io.arff import loadarff
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# %%
############################## DATA #######################################

# %%
# --- récupère les données
def getData(dataset):
    array = []
    for i in dataset[0]:
        try:
            array.append([i['a0'],i['a1']])
        except ValueError:
            array.append([i['x'],i['y']])
    return array

dataRef = (getData(loadarff(open("./donnees/2d-10c.arff",'r'))), 'Données de référence : 2d-10c',9)
dataNconvexe = (getData(loadarff(open("./donnees/rings.arff",'r'))), 'Données non convexes : rings',3)
dataMsep = (getData(loadarff(open("./donnees/elly-2d10c13s.arff",'r'))), 'Données mal séparées : elly-2d10c13s',10)
dataDens = (getData(loadarff(open("./donnees/sizes5.arff",'r'))), 'Données à densité variable : sizes5',4)
dataBruit = (getData(loadarff(open("./donnees/cure-t2-4k.arff",'r'))), 'Données bruitées : cure-t2-4k',7)


dataArray = [dataRef,dataNconvexe,dataMsep,dataDens,dataBruit]

# %%
print(loadarff(open("./donnees/cure-t2-4k.arff",'r')))
# Out:
# (array([(-0.590353 , -0.566736 , b'0'), (-0.147896 , -0.257437 , b'0'),
#        ( 0.0554175, -0.760445 , b'0'), ...,
#        ( 0.4134   ,  0.0177079, b'noise'),
#        ( 0.942855 ,  0.56141  , b'noise'),
#        (-0.174301 ,  0.520809 , b'noise')],
#       dtype=[('x', '<f8'), ('y', '<f8'), ('class', 'S5')]), Dataset: cure-t2-4k
# 	x's type is numeric
# 	y's type is numeric
# 	class's type is nominal, range is ('0', '1', '2', '3', '4', '5', 'noise')
# )

# %%
########################## PLOT ############################################

# %%
# --- plot les données brut
def plotNoColor(dataset):
    data = dataset[0]
    title = dataset[1]
    plt.figure(1)
    plt.title(title)
    for i in range(0,len(data)):
        plt.scatter(data[i][0],data[i][1],color='b')
        
    plt.show()

# %%
# --- plot les données avec une couleur associée à chaque cluster
intToCol = [[np.random.rand(3,)] for c in range(0,800)]

def plotColor(dataset, prediction):
    data = dataset[0]
    title = dataset[1]
    
    plt.figure(figsize=(5,3))
    
    for i in range(0,len(data)):
        col = intToCol[prediction[i]]
        plt.scatter(data[i][0],data[i][1],c=col)
    plt.title(title)
    plt.show()

# %%
###################### EVALUATION ####################################""""""

# %%
def evaluate_score(data,pred):   
    # entre -1 et +1, plus c'est haut, plus c'est dense et bien séparés
    # autour de 0, les clusters se chevauchent
    # plus haut pour les convexes
    val1 = silhouette_score(data,pred)
    #print("silhouette: "+ str(val1))

    # plus c'est haut, plus c'est dense et bien séparés
    # plus haut pour les convexes
    val2 = calinski_harabasz_score(data, pred)
    #print("calinski_harabasz : "+ str(val2))

    # plus bas possible = 0, plus proche de zero = mieux cluster
    # plus haut pour les convexes
    val3 = davies_bouldin_score(data, pred)
    #print( "davies_bouldin : "+ str(val3))

    return (val1,val2,val3)

# %%
########################### kmeans #################################""

# %%
# ------------------------ ALGO KMEANS --------------------------------
def kmean_pred(nb_cluster,data):
    # parametres pour le kmeans
    kmeans = KMeans(n_clusters=nb_cluster,init='k-means++')

    # calcul le temps d'exe
    start = time.time()

    # training
    kmeans.fit(data)

    # prediction
    pred = kmeans.predict(data)
    
    tmps = time.time()-start
    
    return (pred,tmps)

# %%
# ----------------------------- TESTS ------------------------------
# application de kmeans sur le jeux de données de reference
pred, tmps = kmean_pred(dataRef[2],dataRef[0])
print("tmps : " + str(tmps))
plotColor(dataRef,pred)
sil,cal,dav = evaluate_score(dataRef[0],pred)
print("temps d'execution : " +str(tmps))
print("Silhouette coefficient : "+ str(sil))
print("Calinski-Harabasz index : "+ str(cal))
print("Davies-Bouldin index : "+ str(dav))
# Out:
# tmps : 0.09381365776062012
# temps d'execution : 0.09381365776062012
# Silhouette coefficient : 0.8377446510558256
# Calinski-Harabasz index : 48009.63593215639
# Davies-Bouldin index : 0.22821719896766357

# %%
# --- plot les 3 scores et le temps d'execution en fonction du nombre de cluster
def find_nb_clus(dataset, algo_pred):
    data = dataset[0]
    title = dataset[1]
    sil = []
    cal = []
    dav = []
    tmps = []

    rng = range(2,15)
    
    for i in rng:
        # predit avec un nb de cluster
        pred,tmp = algo_pred(i,data)
        tmps.append(tmp)
        # evalue
        a,b,c = evaluate_score(data,pred)
        sil.append(a)
        cal.append(b)
        dav.append(c)
        
    # plot 
    plt.figure(figsize=(9,4))
    plt.suptitle(title)
    plt.subplot(221)
    plt.title('Silhouette Coefficient')
    plt.xlabel('Number of clusters')
    plt.plot(rng,sil,'r')
    
    plt.subplot(222)
    plt.title('Calinski-Harabasz Index')
    plt.xlabel('Number of clusters')
    plt.plot(rng,cal,'b')
    
    plt.subplot(223)
    plt.title('Davies-Bouldin Index')
    plt.xlabel('Number of clusters')
    plt.plot(rng,dav,'g')
    
    plt.subplot(224)
    plt.title('Execution Time')
    plt.ylabel('Time(s)')
    plt.xlabel('Number of clusters')
    plt.plot(rng,tmps,'y')
    plt.subplots_adjust(hspace = 0.6, wspace = 0.3)

# %%
# --- effectue les scores pour le dataset de reference
find_nb_clus(dataRef, kmean_pred)

# %%
# evaluer le nombre de cluster pour tous les dataset
for i in dataArray:
    find_nb_clus(i, kmean_pred)

# %%
# test sur tous les dataset avec le bon nombre de cluster
for i in dataArray:
    pred,tmps = kmean_pred(i[2],i[0])
    plotColor(i,pred)
    sil,cal,dav = evaluate_score(i[0],pred)
    print("temps d'execution : " +str(tmps))
    print("Silhouette coefficient : "+ str(sil))
    print("Calinski-Harabasz index : "+ str(cal))
    print("Davies-Bouldin index : "+ str(dav))
# Out:
# temps d'execution : 0.11048579216003418
# Silhouette coefficient : 0.8377446510558256
# Calinski-Harabasz index : 48009.63593215638
# Davies-Bouldin index : 0.22821719896766357
# temps d'execution : 0.08522891998291016
# Silhouette coefficient : 0.3780953277963173
# Calinski-Harabasz index : 498.4937771607409
# Davies-Bouldin index : 1.0463388421144744
# temps d'execution : 0.47403812408447266
# Silhouette coefficient : 0.40554222106049387
# Calinski-Harabasz index : 2769.473884240745
# Davies-Bouldin index : 0.7420081019584908
# temps d'execution : 0.09959554672241211
# Silhouette coefficient : 0.5725441433007511
# Calinski-Harabasz index : 1042.56207848029
# Davies-Bouldin index : 0.5529514667423887
# temps d'execution : 0.38017940521240234
# Silhouette coefficient : 0.47700589611518474
# Calinski-Harabasz index : 5973.134380755777
# Davies-Bouldin index : 0.7084631127999482

# %%
########################### agglomerate #################################

# %%
def agglo_pred(nb_cluster,link, data):
    # parametres pour le kmeans
    agglo = AgglomerativeClustering(n_clusters=nb_cluster,linkage=link)

    # calcul le temps d'exe
    start = time.time()

    # training
    agglo.fit(data)

    # prediction
    pred = agglo.fit_predict(data)
    
    tmps = time.time()-start
    return (pred,tmps)

# %%
def agglo_pred_ward(nb_clus,data):
    return agglo_pred(nb_clus,'ward',data)

# %%
# test sur le jeu de données de reference et le linkage par défaut ward
pred,tmps = agglo_pred_ward(9,dataRef[0])
print("temps d'execution : "+str(tmps))
plotColor(dataRef,pred)
# Out:
# temps d'execution : 0.9343471527099609

# %%
# test des linkage sur les data ref avec des linkages différents
linkages = ['single','average','complete','ward']
for l in linkages:
    print(" \t Linkage : "+l)
    pred,tmps = agglo_pred(9,l,dataRef[0])
    plotColor(dataRef,pred)
    sil,cal,dav = evaluate_score(dataRef[0],pred)
    print("temps d'execution : " +str(tmps))
    print("Silhouette coefficient : "+ str(sil))
    print("Calinski-Harabasz index : "+ str(cal))
    print("Davies-Bouldin index : "+ str(dav))
# Out:
#  	 Linkage : single
# temps d'execution : 0.3475923538208008
# Silhouette coefficient : 0.7373288555059309
# Calinski-Harabasz index : 17443.354647831755
# Davies-Bouldin index : 0.2696200817951743
#  	 Linkage : average
# temps d'execution : 0.8326380252838135
# Silhouette coefficient : 0.8373633000685332
# Calinski-Harabasz index : 47931.40271262782
# Davies-Bouldin index : 0.2288104436854155
#  	 Linkage : complete
# temps d'execution : 0.8183910846710205
# Silhouette coefficient : 0.6856057085634313
# Calinski-Harabasz index : 25318.401620648398
# Davies-Bouldin index : 0.6068522861630083
#  	 Linkage : ward
# temps d'execution : 0.8786299228668213
# Silhouette coefficient : 0.8374016743635769
# Calinski-Harabasz index : 47740.29038468033
# Davies-Bouldin index : 0.22766794021035228

# %%
# evaluer le nombre de cluster pour tous les dataset
for i in dataArray:
    find_nb_clus(i, agglo_pred_ward)

# %%
linkages = ['single','average','complete','ward']
for link in linkages:
    print("\t Linkage : "+link)
    for i in dataArray:
        pred,tmps = agglo_pred(i[2],link,i[0])
        plotColor(i,pred)
        sil,cal,dav = evaluate_score(i[0],pred)
        print("temps d'execution : " +str(tmps))
        print("Silhouette coefficient : "+ str(sil))
        print("Calinski-Harabasz index : "+ str(cal))
        print("Davies-Bouldin index : "+ str(dav))
# Out:
# 	 Linkage : single
# temps d'execution : 0.1783769130706787
# Silhouette coefficient : 0.7373288555059309
# Calinski-Harabasz index : 17443.354647831755
# Davies-Bouldin index : 0.2696200817951743
# temps d'execution : 0.029921293258666992
# Silhouette coefficient : 0.24802773617217594
# Calinski-Harabasz index : 4.168229129189829
# Davies-Bouldin index : 0.39594044634219655
# temps d'execution : 0.20342469215393066
# Silhouette coefficient : -0.2726151490802538
# Calinski-Harabasz index : 10.01748532776429
# Davies-Bouldin index : 0.6130471392336502
# temps d'execution : 0.023935556411743164
# Silhouette coefficient : 0.11057802380326734
# Calinski-Harabasz index : 3.7631433539238435
# Davies-Bouldin index : 0.4762518985030992
# temps d'execution : 0.30742859840393066
# Silhouette coefficient : -0.46056026140226325
# Calinski-Harabasz index : 5.284148184886305
# Davies-Bouldin index : 1.155795960834226
# 	 Linkage : average
# temps d'execution : 0.4066016674041748
# Silhouette coefficient : 0.8373633000685332
# Calinski-Harabasz index : 47931.40271262782
# Davies-Bouldin index : 0.2288104436854155
# temps d'execution : 0.04587697982788086
# Silhouette coefficient : 0.36559659871651307
# Calinski-Harabasz index : 304.09562531494345
# Davies-Bouldin index : 0.936364072866945
# temps d'execution : 0.2918875217437744
# Silhouette coefficient : 0.3668929730934076
# Calinski-Harabasz index : 2204.2436797490336
# Davies-Bouldin index : 0.7764504317144055
# temps d'execution : 0.06183433532714844
# Silhouette coefficient : 0.5719204478857453
# Calinski-Harabasz index : 990.0948551556619
# Davies-Bouldin index : 0.5618304238574598
# temps d'execution : 0.7498929500579834
# Silhouette coefficient : 0.44641894824713746
# Calinski-Harabasz index : 4818.546185724058
# Davies-Bouldin index : 0.8406222163303825
# 	 Linkage : complete
# temps d'execution : 0.5422728061676025
# Silhouette coefficient : 0.6856057085634313
# Calinski-Harabasz index : 25318.401620648398
# Davies-Bouldin index : 0.6068522861630083
# temps d'execution : 0.05704021453857422
# Silhouette coefficient : 0.33527619227919736
# Calinski-Harabasz index : 434.8154365114414
# Davies-Bouldin index : 1.0293112447041786
# temps d'execution : 0.37699198722839355
# Silhouette coefficient : 0.29240764014894605
# Calinski-Harabasz index : 1781.2204744040996
# Davies-Bouldin index : 0.8266820704679247
# temps d'execution : 0.05226325988769531
# Silhouette coefficient : 0.5204438452400627
# Calinski-Harabasz index : 832.9589949089756
# Davies-Bouldin index : 0.6902627909459628
# temps d'execution : 0.8244478702545166
# Silhouette coefficient : 0.4647828334975353
# Calinski-Harabasz index : 4956.747309555571
# Davies-Bouldin index : 0.6916703423256111
# 	 Linkage : ward
# temps d'execution : 1.2694387435913086
# Silhouette coefficient : 0.8374016743635769
# Calinski-Harabasz index : 47740.29038468033
# Davies-Bouldin index : 0.22766794021035228
# temps d'execution : 0.08776497840881348
# Silhouette coefficient : 0.34639736199824595
# Calinski-Harabasz index : 461.0227113710038
# Davies-Bouldin index : 1.1031462922224398
# temps d'execution : 0.4468090534210205
# Silhouette coefficient : 0.3578842268934078
# Calinski-Harabasz index : 2437.8271801707756
# Davies-Bouldin index : 0.7990118881605911
# temps d'execution : 0.08124661445617676
# Silhouette coefficient : 0.5787821654463462
# Calinski-Harabasz index : 945.9034271575496
# Davies-Bouldin index : 0.49662997862204256
# temps d'execution : 1.2066771984100342
# Silhouette coefficient : 0.42857142944443843
# Calinski-Harabasz index : 5263.117968475869
# Davies-Bouldin index : 0.7301763237668085

# %%
########################## DBSCAN ################################

# %%
from sklearn.cluster import DBSCAN

def dbscan_pred(eps,min_sample,data):
    # parametres pour le kmeans
    dbscan = DBSCAN(eps=eps,min_samples=min_sample)

    # calcul le temps d'exe
    start = time.time()

    # training
    dbscan.fit(data)

    # prediction
    pred = dbscan.fit_predict(data)
    tmps = time.time()-start
    
    return (pred,tmps)

# %%
pred,tmps = dbscan_pred(5.0,10,dataRef[0])
plotColor(dataRef[0],pred)

# %%
# test des parametres eps
for i in np.arange(1.0,10.0,1.0):
    print('eps = '+ str(i))
    pred,tmps = dbscan_pred(i,10,dataRef[0])
    plotColor(dataRef[0],pred)
# Out:
# eps = 1.0
# eps = 2.0
# eps = 3.0
# eps = 4.0
# eps = 5.0
# eps = 6.0
# eps = 7.0
# eps = 8.0
# eps = 9.0

# %%
# test des parametres min_sample
for i in range(1,15):
    print('min-sample = '+ str(i))
    pred,tmps = dbscan_pred(4.0,i,dataRef[0])
    plotColor(dataRef[0],pred)
# Out:
# min-sample = 1
# min-sample = 2
# min-sample = 3
# min-sample = 4
# min-sample = 5
# min-sample = 6
# min-sample = 7
# min-sample = 8
# min-sample = 9
# min-sample = 10
# min-sample = 11
# min-sample = 12
# min-sample = 13
# min-sample = 14

# %%
# test des parametres eps ET min-sample
for eps in np.arange(1.0,10.0,2.0):
    for min_sample in range(1,15,2):
        print('eps = '+ str(eps))
        print('min-sample = '+ str(min_sample)) 
         
        pred,tmps = dbscan_pred(eps,min_sample,dataRef[0])
                              
        sil,cal,dav = evaluate_score(dataRef[0],pred)
        print('sil : '+ str(sil))
        print('cal : '+ str(cal))
        print('dav : '+ str(dav))
              
        plotColor(dataRef[0],pred)
# Out:
# eps = 1.0
# min-sample = 1
# sil : 0.16387420614692558
# cal : 3584.7345718315387
# dav : 0.44792112386147936
# eps = 1.0
# min-sample = 3
# sil : 0.4148670651399852
# cal : 1239.1388418701586
# dav : 1.0440635070789177
# eps = 1.0
# min-sample = 5
# sil : 0.4593930658025584
# cal : 1105.2765676616366
# dav : 1.1293131032021348
# eps = 1.0
# min-sample = 7
# sil : 0.447535008887289
# cal : 755.5878296243279
# dav : 1.0973181030515193
# eps = 1.0
# min-sample = 9
# sil : 0.458682040048421
# cal : 647.3784861830632
# dav : 1.1962314317283826
# eps = 1.0
# min-sample = 11
# sil : 0.4126936786164132
# cal : 673.8348779900417
# dav : 1.2055747931540606
# eps = 1.0
# min-sample = 13
# sil : 0.25191692698131335
# cal : 514.6142259959183
# dav : 1.1691601379607013
# eps = 3.0
# min-sample = 1
# sil : 0.4154164637376692
# cal : 8308.541259574067
# dav : 0.4817555150313828
# eps = 3.0
# min-sample = 3
# sil : 0.7733470827465355
# cal : 15078.938576862205
# dav : 1.1292898464291063
# eps = 3.0
# min-sample = 5
# sil : 0.8335411505260097
# cal : 29027.9137782882
# dav : 1.0817172477755368
# eps = 3.0
# min-sample = 7
# sil : 0.8326092928033721
# cal : 26404.43837055006
# dav : 1.0992042202728323
# eps = 3.0
# min-sample = 9
# sil : 0.8321188546424285
# cal : 25361.844212359763
# dav : 1.1288939167611267
# eps = 3.0
# min-sample = 11
# sil : 0.8292146343918
# cal : 21683.08246197532
# dav : 1.0967879765224864
# eps = 3.0
# min-sample = 13
# sil : 0.8260178579421974
# cal : 19532.45297670341
# dav : 1.0967933681815756
# eps = 5.0
# min-sample = 1
# sil : 0.7373288555059309
# cal : 17443.35464783175
# dav : 0.26962008179517427
# eps = 5.0
# min-sample = 3
# sil : 0.7373288555059309
# cal : 17443.35464783175
# dav : 0.26962008179517427
# eps = 5.0
# min-sample = 5
# sil : 0.7373288555059309
# cal : 17443.35464783175
# dav : 0.26962008179517427
# eps = 5.0
# min-sample = 7
# sil : 0.7373288555059309
# cal : 17443.35464783175
# dav : 0.26962008179517427
# eps = 5.0
# min-sample = 9
# sil : 0.7373288555059309
# cal : 17443.35464783175
# dav : 0.26962008179517427
# eps = 5.0
# min-sample = 11
# sil : 0.7373288555059309
# cal : 17443.35464783175
# dav : 0.26962008179517427
# eps = 5.0
# min-sample = 13
# sil : 0.7373288555059309
# cal : 17443.35464783175
# dav : 0.26962008179517427
# eps = 7.0
# min-sample = 1
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 7.0
# min-sample = 3
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 7.0
# min-sample = 5
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 7.0
# min-sample = 7
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 7.0
# min-sample = 9
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 7.0
# min-sample = 11
# sil : 0.7771329700076133
# cal : 19931.738270015536
# dav : 0.27411504115090624
# eps = 7.0
# min-sample = 13
# sil : 0.7771329700076133
# cal : 19931.738270015536
# dav : 0.27411504115090624
# eps = 9.0
# min-sample = 1
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 9.0
# min-sample = 3
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 9.0
# min-sample = 5
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 9.0
# min-sample = 7
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 9.0
# min-sample = 9
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 9.0
# min-sample = 11
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737
# eps = 9.0
# min-sample = 13
# sil : 0.7525629204969061
# cal : 14975.373577345592
# dav : 0.2767188824821737

# %%
## rq : faire une courbe des scores en fonction des valeurs de eps et min-range pour plus de clarete

def find_param_dbscan(data):


    rng_eps = np.arange(1.0,10.0,1.0)
    rng_min_sample = range(1,15,1)
    
    for eps in rng_eps:
        sil = []
        cal = []
        dav = []
        tmps = []
        for min_sample in rng_min_sample:
            # predit avec des valeur de min et eps
            pred,tmp = dbscan_pred(eps,min_sample,data)
            tmps.append(tmp)
            
            # evalue
            a,b,c = evaluate_score(data,pred)
            sil.append(a)
            cal.append(b)
            dav.append(c)
       
        # plot 
        plt.figure()
        fig,axs = plt.subplots(4, 1)
        axs[0].plot(rng_min_sample,sil,'r')
        axs[0].set_title('Eps : ' + str(eps) + ' pour sil')
        #plt.figure()
        axs[1].plot(rng_min_sample,cal,'b')
        axs[1].set_title('Eps : ' + str(eps) + ' pour cal')
        #plt.figure()
        axs[2].plot(rng_min_sample,dav,'g')
        axs[2].set_title('Eps : ' + str(eps) + ' pour dav')
        #plt.figure()
        axs[3].plot(rng_min_sample,tmps,'y')
        axs[3].set_title('Eps : ' + str(eps) + ' temps')


#https://matplotlib.org/devdocs/gallery/subplots_axes_and_figures/subplots_demo.html

# %%
find_param_dbscan(dataRef[0])
# ajouter le nom de chaque courbe

# %%
# meilleure combinaison : min-sample = 10 et eps = 4
# application a tous les dataset

for data in dataArray:
    print(data[1])
    find_param_dbscan(data[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f11a00e87f6> in <module>
#       2 # application a tous les dataset
#       3
# ----> 4 for data in dataArray:
#       5     print(data[1])
#       6     find_param_dbscan(data[0])
#
# NameError: name 'dataArray' is not defined

# %%
################################## HDBSCAN ###################################

# %%
import hdbscan

clusterer = hdbscan.HDBSCAN(min_samples=10)
#pred = clusterer.fit_predict(dataRef[0])

# %%
for data in dataArray:
    tmp = time.time()
    pred = clusterer.fit_predict(data[0])
    print(str(time.time() - tmp))
    plotColor(data[0], pred)
# Out:
# 0.041916608810424805
# 0.01316070556640625
# 0.0382075309753418
# 0.020277023315429688
# 0.05948662757873535
